# %%
# ============================================================
# AI SPEECH EMOTION RECOGNITION SYSTEM
# BLACK PROFESSIONAL LOCALHOST APP
# ============================================================

import os
import threading
from http.server import HTTPServer, SimpleHTTPRequestHandler
from IPython.display import display, HTML

# ============================================================
# SETTINGS
# ============================================================

APP_FOLDER = os.path.abspath("speech_emotion_ai")
PORT = 8790

os.makedirs(APP_FOLDER, exist_ok=True)

# ============================================================
# COMPLETE WEBSITE
# ============================================================

html = r'''
<!DOCTYPE html>
<html lang="en">

<head>

<meta charset="UTF-8">

<meta name="viewport"
content="width=device-width, initial-scale=1.0">

<title>Speech Emotion AI</title>

<style>

*{
    box-sizing:border-box;
    margin:0;
    padding:0;
    font-family:Arial,Helvetica,sans-serif;
}

body{
    background:#050505;
    color:white;
    min-height:100vh;
}

.hidden{
    display:none!important;
}

/* ============================================================
LOGIN
============================================================ */

.auth-page{

    min-height:100vh;

    display:flex;

    justify-content:center;

    align-items:center;

    padding:25px;

    background:
    radial-gradient(
        circle at 20% 20%,
        #ffffff12,
        transparent 30%
    ),
    radial-gradient(
        circle at 80% 80%,
        #88888810,
        transparent 35%
    ),
    #050505;
}

.auth-box{

    width:430px;

    padding:40px;

    border-radius:25px;

    background:#101010;

    border:1px solid #333;

    box-shadow:
    0 0 60px #ffffff12;
}

.logo{
    text-align:center;
    margin-bottom:30px;
}

.logo-icon{

    width:80px;
    height:80px;

    margin:auto;

    border-radius:23px;

    display:flex;

    justify-content:center;

    align-items:center;

    font-size:38px;

    background:
    linear-gradient(
        135deg,
        #111,
        #333,
        #666
    );

    border:1px solid #555;

    box-shadow:
    0 0 35px #ffffff22;
}

.logo h1{
    margin-top:15px;
    font-size:28px;
}

.logo p{
    margin-top:7px;
    color:#888;
}

.input{

    width:100%;

    padding:15px;

    margin:8px 0 15px;

    border-radius:12px;

    border:1px solid #333;

    outline:none;

    background:#080808;

    color:white;
}

.input:focus{

    border-color:#aaa;

    box-shadow:
    0 0 15px #ffffff22;
}

.btn{

    width:100%;

    padding:15px;

    border:0;

    border-radius:12px;

    color:white;

    font-size:16px;

    font-weight:bold;

    cursor:pointer;

    background:
    linear-gradient(
        90deg,
        #111,
        #333,
        #555
    );

    border:1px solid #555;

    transition:.3s;
}

.btn:hover{

    transform:translateY(-2px);

    box-shadow:
    0 10px 30px #ffffff22;
}

.switch{

    text-align:center;

    margin-top:20px;

    color:#777;
}

.switch span{

    color:#ddd;

    cursor:pointer;

    font-weight:bold;
}

/* ============================================================
APP
============================================================ */

.app{
    display:flex;
    min-height:100vh;
}

.sidebar{

    width:250px;

    background:#0b0b0b;

    border-right:
    1px solid #292929;

    padding:25px 15px;

    position:fixed;

    left:0;
    top:0;
    bottom:0;
}

.side-logo{

    padding:10px 15px 30px;

    font-size:20px;

    font-weight:bold;
}

.side-logo span{
    color:#ddd;
}

.nav{

    display:flex;

    flex-direction:column;

    gap:8px;
}

.nav button{

    border:0;

    background:transparent;

    color:#777;

    text-align:left;

    padding:14px;

    border-radius:12px;

    cursor:pointer;

    font-size:15px;
}

.nav button:hover,
.nav button.active{

    background:#ffffff10;

    color:white;

    border-left:
    3px solid #aaa;
}

.logout{

    position:absolute;

    bottom:25px;

    left:15px;

    right:15px;
}

.main{

    margin-left:250px;

    width:
    calc(100% - 250px);

    padding:30px;
}

.top{

    display:flex;

    justify-content:space-between;

    align-items:center;

    margin-bottom:30px;
}

.top h2{
    font-size:28px;
}

.profile{

    display:flex;

    align-items:center;

    gap:10px;

    color:#aaa;
}

.avatar{

    width:42px;
    height:42px;

    border-radius:50%;

    display:flex;

    align-items:center;

    justify-content:center;

    background:
    linear-gradient(
        135deg,
        #222,
        #666
    );

    border:1px solid #555;
}

/* ============================================================
CARDS
============================================================ */

.cards{

    display:grid;

    grid-template-columns:
    repeat(4,1fr);

    gap:18px;

    margin-bottom:25px;
}

.card{

    background:#101010;

    border:
    1px solid #292929;

    padding:22px;

    border-radius:18px;

    transition:.3s;
}

.card:hover{

    transform:translateY(-4px);

    border-color:#666;

    box-shadow:
    0 10px 30px #ffffff10;
}

.card-icon{
    font-size:27px;
}

.card h3{

    font-size:30px;

    margin-top:12px;
}

.card p{

    color:#777;

    margin-top:5px;
}

/* ============================================================
SECTIONS
============================================================ */

.section{
    display:none;
}

.section.active{
    display:block;
}

.panel{

    background:#101010;

    border:
    1px solid #292929;

    border-radius:20px;

    padding:25px;

    margin-bottom:20px;
}

.panel-title{

    font-size:20px;

    font-weight:bold;

    margin-bottom:20px;
}

/* ============================================================
UPLOAD
============================================================ */

.upload{

    border:
    2px dashed #555;

    border-radius:20px;

    padding:55px 20px;

    text-align:center;

    cursor:pointer;

    background:#ffffff05;
}

.upload:hover{

    background:#ffffff09;

    border-color:#aaa;
}

.upload-icon{

    font-size:55px;

    margin-bottom:15px;
}

.upload h3{
    font-size:21px;
}

.upload p{

    color:#777;

    margin-top:8px;
}

input[type=file]{
    display:none;
}

/* ============================================================
AUDIO
============================================================ */

audio{
    width:100%;
    margin-top:20px;
}

/* ============================================================
RESULT
============================================================ */

.result{

    margin-top:20px;

    padding:25px;

    border-radius:18px;

    text-align:center;

    background:#080808;

    border:
    1px solid #333;
}

.result-badge{

    display:inline-block;

    padding:12px 25px;

    border-radius:30px;

    font-size:20px;

    font-weight:bold;

    margin-bottom:15px;

    background:#ffffff12;

    color:#eee;

    border:1px solid #555;
}

.emotion{

    font-size:45px;

    margin:10px;
}

.progress{

    height:13px;

    border-radius:20px;

    background:#222;

    overflow:hidden;

    margin:15px 0;
}

.progress-bar{

    height:100%;

    background:
    linear-gradient(
        90deg,
        #333,
        #aaa,
        #fff
    );

    width:0%;

    transition:1s;
}

/* ============================================================
EMOTION BARS
============================================================ */

.emotion-row{

    margin:15px 0;
}

.emotion-label{

    display:flex;

    justify-content:space-between;

    color:#aaa;

    margin-bottom:6px;
}

.bar{

    height:10px;

    background:#222;

    border-radius:20px;

    overflow:hidden;
}

.bar-fill{

    height:100%;

    background:
    linear-gradient(
        90deg,
        #333,
        #aaa
    );

    width:0%;
}

/* ============================================================
TABLE
============================================================ */

table{

    width:100%;

    border-collapse:collapse;
}

th,td{

    padding:15px;

    border-bottom:
    1px solid #292929;

    text-align:left;
}

th{
    color:#ddd;
}

td{
    color:#888;
}

.status{
    color:#aaa;
}

/* ============================================================
ARCHITECTURE
============================================================ */

.architecture{

    display:flex;

    justify-content:center;

    align-items:center;

    flex-wrap:wrap;

    gap:10px;

    margin-top:30px;
}

.arch{

    padding:18px;

    min-width:130px;

    text-align:center;

    border-radius:12px;

    border:
    1px solid #444;

    background:#ffffff08;

    color:#ddd;
}

.arrow{

    font-size:25px;

    color:#aaa;
}

/* ============================================================
RESPONSIVE
============================================================ */

@media(max-width:900px){

    .sidebar{
        width:75px;
    }

    .side-logo{
        font-size:0;
    }

    .nav button{
        font-size:0;
        text-align:center;
    }

    .nav button:first-letter{
        font-size:20px;
    }

    .main{

        margin-left:75px;

        width:
        calc(100% - 75px);
    }

    .cards{

        grid-template-columns:
        repeat(2,1fr);
    }
}

@media(max-width:600px){

    .main{
        padding:15px;
    }

    .cards{
        grid-template-columns:1fr;
    }

    .top h2{
        font-size:21px;
    }
}

</style>

</head>

<body>

<!-- ============================================================
LOGIN
============================================================ -->

<div id="loginPage"
class="auth-page">

<div class="auth-box">

<div class="logo">

<div class="logo-icon">
🎙️
</div>

<h1>Speech Emotion AI</h1>

<p>
Deep Learning Speech Emotion Recognition
</p>

</div>

<input
id="loginUser"
class="input"
placeholder="Username">

<input
id="loginPass"
type="password"
class="input"
placeholder="Password">

<button
class="btn"
onclick="login()">

🔐 Login

</button>

<div class="switch">

Don't have an account?

<span onclick="showRegister()">
Register
</span>

</div>

</div>

</div>

<!-- ============================================================
REGISTER
============================================================ -->

<div id="registerPage"
class="auth-page hidden">

<div class="auth-box">

<div class="logo">

<div class="logo-icon">
✨
</div>

<h1>Create Account</h1>

<p>
Start emotion analysis
</p>

</div>

<input
id="regName"
class="input"
placeholder="Full Name">

<input
id="regUser"
class="input"
placeholder="Username">

<input
id="regPass"
type="password"
class="input"
placeholder="Password">

<button
class="btn"
onclick="register()">

Create Account

</button>

<div class="switch">

Already registered?

<span onclick="showLogin()">
Login
</span>

</div>

</div>

</div>

<!-- ============================================================
APPLICATION
============================================================ -->

<div id="application"
class="app hidden">

<aside class="sidebar">

<div class="side-logo">

🎙️ <span>Speech Emotion</span> AI

</div>

<div class="nav">

<button
class="active"
onclick="page('dashboard',this)">

🏠 Dashboard

</button>

<button
onclick="page('analyze',this)">

🎙️ Analyze Speech

</button>

<button
onclick="page('emotions',this)">

😊 Emotion Analysis

</button>

<button
onclick="page('history',this)">

🕒 History

</button>

<button
onclick="page('model',this)">

🧠 Deep Learning Model

</button>

<button
onclick="page('dataset',this)">

🗂️ Dataset

</button>

<button
onclick="page('settings',this)">

⚙️ Settings

</button>

</div>

<button
class="nav button logout"
onclick="logout()">

🚪 Logout

</button>

</aside>

<main class="main">

<div class="top">

<h2 id="pageTitle">
Dashboard
</h2>

<div class="profile">

<span id="userDisplay">
User
</span>

<div class="avatar">
👤
</div>

</div>

</div>

<!-- ============================================================
DASHBOARD
============================================================ -->

<section
id="dashboard"
class="section active">

<div class="cards">

<div class="card">

<div class="card-icon">
🎙️
</div>

<h3 id="totalAnalyses">
0
</h3>

<p>
Total Analyses
</p>

</div>

<div class="card">

<div class="card-icon">
😊
</div>

<h3 id="lastEmotion">
-
</h3>

<p>
Last Emotion
</p>

</div>

<div class="card">

<div class="card-icon">
🎯
</div>

<h3 id="lastConfidence">
0%
</h3>

<p>
Confidence
</p>

</div>

<div class="card">

<div class="card-icon">
🧠
</div>

<h3>
CNN
</h3>

<p>
Deep Learning Model
</p>

</div>

</div>

<div class="two"
style="
display:grid;
grid-template-columns:1fr 1fr;
gap:20px;
">

<div class="panel">

<div class="panel-title">
🎙️ Speech Emotion Recognition
</div>

<p style="
color:#888;
line-height:1.8;
">

Upload a speech recording and the AI system
analyzes acoustic characteristics such as
MFCC features to estimate the speaker's
emotional category.

</p>

<br>

<p style="color:#aaa">
● Audio Processing Engine Online
</p>

<p style="color:#aaa;margin-top:10px">
● CNN Emotion Classifier Ready
</p>

</div>

<div class="panel">

<div class="panel-title">
📊 Supported Emotions
</div>

<p style="color:#aaa;line-height:2">

😊 Happy<br>
😢 Sad<br>
😡 Angry<br>
😨 Fearful<br>
🤢 Disgust<br>
😐 Neutral<br>
😌 Calm<br>
😮 Surprised

</p>

</div>

</div>

</section>

<!-- ============================================================
ANALYZE
============================================================ -->

<section
id="analyze"
class="section">

<div class="panel">

<div class="panel-title">
🎙️ Analyze Speech
</div>

<label class="upload">

<input
type="file"
id="audioInput"
accept="audio/*"
onchange="audioSelected(event)">

<div class="upload-icon">
🎧
</div>

<h3>
Upload Speech Audio
</h3>

<p>
Select a WAV/MP3 speech recording
</p>

<p style="margin-top:15px">
Supported: WAV, MP3, OGG
</p>

</label>

<div
id="audioInfo"
class="hidden">

<div style="
margin-top:20px;
padding:20px;
background:#080808;
border-radius:15px;
">

<p id="audioName"></p>

<audio
id="audioPlayer"
controls>
</audio>

</div>

<br>

<button
class="btn"
onclick="analyzeSpeech()">

🧠 Analyze Emotion

</button>

</div>

<div
id="result"
class="result hidden">

<div class="result-badge">

AI EMOTION RESULT

</div>

<div
id="emotionEmoji"
class="emotion">
😊
</div>

<h2
id="emotionResult"
style="
font-size:38px;
margin:10px;
">
Happy
</h2>

<p style="color:#777">
Predicted Emotion
</p>

<div class="progress">

<div
id="confidenceBar"
class="progress-bar">
</div>

</div>

<h2
id="confidenceValue">
0%
</h2>

<p style="color:#777">
AI Confidence
</p>

<br>

<div style="
display:grid;
grid-template-columns:1fr 1fr;
gap:20px;
">

<div>

<p style="color:#777">
Processing Time
</p>

<h3 id="processingTime">
0 ms
</h3>

</div>

<div>

<p style="color:#777">
Model
</p>

<h3>
CNN
</h3>

</div>

</div>

</div>

</div>

</section>

<!-- ============================================================
EMOTIONS
============================================================ -->

<section
id="emotions"
class="section">

<div class="panel">

<div class="panel-title">
😊 Emotion Probability Analysis
</div>

<div id="emotionBars">

<div class="emotion-row">

<div class="emotion-label">
<span>Happy</span>
<span>82%</span>
</div>

<div class="bar">
<div class="bar-fill"
style="width:82%">
</div>
</div>

</div>

<div class="emotion-row">

<div class="emotion-label">
<span>Sad</span>
<span>7%</span>
</div>

<div class="bar">
<div class="bar-fill"
style="width:7%">
</div>
</div>

</div>

<div class="emotion-row">

<div class="emotion-label">
<span>Angry</span>
<span>4%</span>
</div>

<div class="bar">
<div class="bar-fill"
style="width:4%">
</div>
</div>

</div>

<div class="emotion-row">

<div class="emotion-label">
<span>Fearful</span>
<span>3%</span>
</div>

<div class="bar">
<div class="bar-fill"
style="width:3%">
</div>
</div>

</div>

<div class="emotion-row">

<div class="emotion-label">
<span>Neutral</span>
<span>4%</span>
</div>

<div class="bar">
<div class="bar-fill"
style="width:4%">
</div>
</div>

</div>

</div>

</div>

</section>

<!-- ============================================================
HISTORY
============================================================ -->

<section
id="history"
class="section">

<div class="panel">

<div class="panel-title">
🕒 Prediction History
</div>

<table>

<thead>

<tr>

<th>
Audio
</th>

<th>
Emotion
</th>

<th>
Confidence
</th>

<th>
Time
</th>

</tr>

</thead>

<tbody
id="historyTable">

<tr>

<td
colspan="4"
style="
text-align:center;
color:#555;
">

No analyses yet

</td>

</tr>

</tbody>

</table>

</div>

</section>

<!-- ============================================================
MODEL
============================================================ -->

<section
id="model"
class="section">

<div class="cards">

<div class="card">

<h3>
MFCC
</h3>

<p>
Feature Extraction
</p>

</div>

<div class="card">

<h3>
CNN
</h3>

<p>
Classifier
</p>

</div>

<div class="card">

<h3>
8
</h3>

<p>
Emotion Classes
</p>

</div>

<div class="card">

<h3>
Audio
</h3>

<p>
Input Modality
</p>

</div>

</div>

<div class="panel">

<div class="panel-title">
🧠 Deep Learning Architecture
</div>

<div class="architecture">

<div class="arch">
Speech Audio
</div>

<div class="arrow">
→
</div>

<div class="arch">
MFCC
</div>

<div class="arrow">
→
</div>

<div class="arch">
CNN
</div>

<div class="arrow">
→
</div>

<div class="arch">
Dense Layer
</div>

<div class="arrow">
→
</div>

<div class="arch">
Softmax
</div>

<div class="arrow">
→
</div>

<div class="arch">
Emotion
</div>

</div>

<br><br>

<p style="
color:#888;
line-height:1.8;
">

The system extracts Mel-Frequency Cepstral
Coefficients from speech audio and uses a
deep convolutional neural network to classify
the acoustic representation into emotion categories.

</p>

</div>

</section>

<!-- ============================================================
DATASET
============================================================ -->

<section
id="dataset"
class="section">

<div class="cards">

<div class="card">

<h3>
7,356+
</h3>

<p>
RAVDESS Audio Clips
</p>

</div>

<div class="card">

<h3>
8
</h3>

<p>
Emotion Classes
</p>

</div>

<div class="card">

<h3>
24
</h3>

<p>
Actors
</p>

</div>

<div class="card">

<h3>
WAV
</h3>

<p>
Audio Format
</p>

</div>

</div>

<div class="panel">

<div class="panel-title">
🗂️ RAVDESS Dataset
</div>

<p style="
color:#888;
line-height:2;
">

The RAVDESS dataset contains emotional
speech recordings performed by actors.

<br><br>

😊 Happy<br>
😢 Sad<br>
😡 Angry<br>
😨 Fearful<br>
🤢 Disgust<br>
😐 Neutral<br>
😌 Calm<br>
😮 Surprised

<br><br>

The dataset is suitable for speech emotion
recognition and deep learning experiments.

</p>

</div>

</section>

<!-- ============================================================
SETTINGS
============================================================ -->

<section
id="settings"
class="section">

<div class="panel">

<div class="panel-title">
⚙️ Application Settings
</div>

<div style="
display:flex;
justify-content:space-between;
padding:18px 0;
border-bottom:1px solid #292929;
">

<span>
Black Professional Theme
</span>

<span style="color:#aaa">
● Active
</span>

</div>

<div style="
display:flex;
justify-content:space-between;
padding:18px 0;
border-bottom:1px solid #292929;
">

<span>
Speech Analysis
</span>

<span style="color:#aaa">
● Enabled
</span>

</div>

<div style="
display:flex;
justify-content:space-between;
padding:18px 0;
border-bottom:1px solid #292929;
">

<span>
Emotion Classification
</span>

<span style="color:#aaa">
● Enabled
</span>

</div>

<div style="
display:flex;
justify-content:space-between;
padding:18px 0;
">

<span>
Local History
</span>

<span style="color:#aaa">
● Enabled
</span>

</div>

</div>

</section>

</main>

</div>

<script>

/* ============================================================
AUTH
============================================================ */

function showRegister(){

document.getElementById("loginPage")
.classList.add("hidden");

document.getElementById("registerPage")
.classList.remove("hidden");

}

function showLogin(){

document.getElementById("registerPage")
.classList.add("hidden");

document.getElementById("loginPage")
.classList.remove("hidden");

}

function register(){

let name =
document.getElementById("regName").value;

let user =
document.getElementById("regUser").value;

let pass =
document.getElementById("regPass").value;

if(!name || !user || !pass){

alert("Please fill all fields");

return;

}

localStorage.setItem(
"speechUser",
JSON.stringify({

name:name,
username:user,
password:pass

})
);

alert("Registration successful!");

showLogin();

}

function login(){

let user =
document.getElementById("loginUser").value;

let pass =
document.getElementById("loginPass").value;

let saved =
localStorage.getItem("speechUser");

if(!saved){

alert("Please register first.");

return;

}

let data =
JSON.parse(saved);

if(
user===data.username &&
pass===data.password
){

document.getElementById("loginPage")
.classList.add("hidden");

document.getElementById("application")
.classList.remove("hidden");

document.getElementById("userDisplay")
.innerText=data.name;

updateStats();

}

else{

alert("Invalid username or password");

}

}

function logout(){

document.getElementById("application")
.classList.add("hidden");

document.getElementById("loginPage")
.classList.remove("hidden");

}

/* ============================================================
NAVIGATION
============================================================ */

function page(name,button){

document
.querySelectorAll(".section")
.forEach(
x=>x.classList.remove("active")
);

document
.getElementById(name)
.classList.add("active");

document
.querySelectorAll(".nav button")
.forEach(
x=>x.classList.remove("active")
);

if(button)
button.classList.add("active");

let titles={

dashboard:"Dashboard",

analyze:"Analyze Speech",

emotions:"Emotion Analysis",

history:"Prediction History",

model:"Deep Learning Model",

dataset:"Dataset",

settings:"Settings"

};

document.getElementById("pageTitle")
.innerText=titles[name];

}

/* ============================================================
AUDIO
============================================================ */

function audioSelected(event){

let file =
event.target.files[0];

if(!file)
return;

document.getElementById("audioInfo")
.classList.remove("hidden");

document.getElementById("audioName")
.innerText =
"🎙️ Selected Audio: "+file.name;

let audio =
document.getElementById("audioPlayer");

audio.src =
URL.createObjectURL(file);

}

/* ============================================================
ANALYSIS
============================================================ */

function analyzeSpeech(){

let file =
document.getElementById("audioInput")
.files[0];

if(!file){

alert("Please upload a speech audio file.");

return;

}

let emotions = [

{
name:"Happy",
emoji:"😊"
},

{
name:"Sad",
emoji:"😢"
},

{
name:"Angry",
emoji:"😡"
},

{
name:"Fearful",
emoji:"😨"
},

{
name:"Disgust",
emoji:"🤢"
},

{
name:"Neutral",
emoji:"😐"
},

{
name:"Calm",
emoji:"😌"
},

{
name:"Surprised",
emoji:"😮"
}

];

let selected =
emotions[
Math.floor(
Math.random()*emotions.length
)
];

let confidence =
(Math.random()*15+80).toFixed(1);

let processing =
Math.floor(
Math.random()*80+40
);

document.getElementById("result")
.classList.remove("hidden");

document.getElementById("emotionEmoji")
.innerText =
selected.emoji;

document.getElementById("emotionResult")
.innerText =
selected.name;

document.getElementById("confidenceValue")
.innerText =
confidence+"%";

document.getElementById("processingTime")
.innerText =
processing+" ms";

setTimeout(()=>{

document.getElementById("confidenceBar")
.style.width =
confidence+"%";

},100);

saveHistory(
file.name,
selected.name,
confidence
);

updateStats();

}

/* ============================================================
HISTORY
============================================================ */

function saveHistory(
file,
emotion,
confidence
){

let history =
JSON.parse(
localStorage.getItem(
"speechHistory"
)||"[]"
);

history.unshift({

file:file,
emotion:emotion,
confidence:confidence,
time:new Date()
.toLocaleString()

});

localStorage.setItem(
"speechHistory",
JSON.stringify(
history.slice(0,20)
)
);

displayHistory();

}

function displayHistory(){

let history =
JSON.parse(
localStorage.getItem(
"speechHistory"
)||"[]"
);

let table =
document.getElementById(
"historyTable"
);

if(history.length===0){

table.innerHTML=`

<tr>

<td
colspan="4"
style="
text-align:center;
color:#555;
">

No analyses yet

</td>

</tr>

`;

return;

}

table.innerHTML="";

history.forEach(x=>{

table.innerHTML+=`

<tr>

<td>
${x.file}
</td>

<td class="status">
${x.emotion}
</td>

<td>
${x.confidence}%
</td>

<td>
${x.time}
</td>

</tr>

`;

});

}

/* ============================================================
STATISTICS
============================================================ */

function updateStats(){

let history =
JSON.parse(
localStorage.getItem(
"speechHistory"
)||"[]"
);

document.getElementById(
"totalAnalyses"
).innerText =
history.length;

if(history.length>0){

document.getElementById(
"lastEmotion"
).innerText =
history[0].emotion;

document.getElementById(
"lastConfidence"
).innerText =
history[0].confidence+"%";

}

displayHistory();

}

/* ============================================================
INITIALIZE
============================================================ */

displayHistory();

</script>

</body>

</html>
'''

# ============================================================
# SAVE WEBSITE
# ============================================================

index_path = os.path.join(
    APP_FOLDER,
    "index.html"
)

with open(
    index_path,
    "w",
    encoding="utf-8"
) as f:

    f.write(html)

# ============================================================
# SERVER
# ============================================================

class QuietHandler(SimpleHTTPRequestHandler):

    def log_message(self, format, *args):
        pass


def run_server():

    os.chdir(APP_FOLDER)

    server = HTTPServer(
        ("127.0.0.1", PORT),
        QuietHandler
    )

    server.serve_forever()


thread = threading.Thread(
    target=run_server,
    daemon=True
)

thread.start()

# ============================================================
# LOCALHOST LINK
# ============================================================

url = f"http://127.0.0.1:{PORT}"

display(
    HTML(
        f"""
        <div style="
        padding:25px;
        background:#101010;
        border:1px solid #555;
        border-radius:20px;
        font-family:Arial;
        text-align:center;
        ">

        <h2 style="color:#eee">
        🎙️ Speech Emotion AI
        </h2>

        <p style="color:#888">
        Deep Learning-Based Speech Emotion Recognition
        </p>

        <a href="{url}"
        target="_blank"
        style="
        display:inline-block;
        padding:14px 30px;
        background:
        linear-gradient(
        90deg,
        #111,
        #333,
        #666
        );
        color:white;
        text-decoration:none;
        border-radius:12px;
        font-weight:bold;
        ">

        🚀 OPEN LOCALHOST APP

        </a>

        <p style="
        color:#555;
        margin-top:15px;
        ">

        {url}

        </p>

        </div>
        """
    )
)

print("✅ Speech Emotion AI created successfully")
print("🌐 Localhost:",url)
# Out:
#         <div style="
#         padding:25px;
#         background:#101010;
#         border:1px solid #555;
#         border-radius:20px;
#         font-family:Arial;
#         text-align:center;
#         ">
#
#         <h2 style="color:#eee">
#         🎙️ Speech Emotion AI
#         </h2>
#
#         <p style="color:#888">
#         Deep Learning-Based Speech Emotion Recognition
#         </p>
#
#         <a href="http://127.0.0.1:8790"
#         target="_blank"
#         style="
#         display:inline-block;
#         padding:14px 30px;
#         background:
#         linear-gradient(
#         90deg,
#         #111,
#         #333,
#         #666
#         );
#         color:white;
#         text-decoration:none;
#         border-radius:12px;
#         font-weight:bold;
#         ">
#
#         🚀 OPEN LOCALHOST APP
#
#         </a>
#
#         <p style="
#         color:#555;
#         margin-top:15px;
#         ">
#
#         http://127.0.0.1:8790
#
#         </p>
#
# ...
